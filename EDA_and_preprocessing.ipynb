# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
import lightgbm
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier
import catboost
from bayes_opt import BayesianOptimization

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import plotly.express as px
import umap

from sklearn.linear_model import LogisticRegression
from scipy import stats

# %%
# data 불러오기, 결측치, 중복값 확인 및 드랍 
data = pd.read_csv('./data/train.csv')

# %%
data.info() # 51047개의 데이터 dtypes: float64(26), int64(9), object(23)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
#  13  CustomerCareCalls          51047 non-null  float64
#  14  ThreewayCalls              51047 non-null  float64
#  15  ReceivedCalls              51047 non-null  float64
#  16  OutboundCalls              51047 non-null  float64
#  17  InboundCalls               51047 non-null  float64
#  18  PeakCallsInOut             51047 non-null  float64
#  19  OffPeakCallsInOut          51047 non-null  float64
#  20  DroppedBlockedCalls        51047 non-null  float64
#  21  CallForwardingCalls        51047 non-null  float64
#  22  CallWaitingCalls           51047 non-null  float64
#  23  MonthsInService            51047 non-null  int64
#  24  UniqueSubs                 51047 non-null  int64
#  25  ActiveSubs                 51047 non-null  int64
#  26  ServiceArea                51023 non-null  object
#  27  Handsets                   51046 non-null  float64
#  28  HandsetModels              51046 non-null  float64
#  29  CurrentEquipmentDays       51046 non-null  float64
#  30  AgeHH1                     50138 non-null  float64
#  31  AgeHH2                     50138 non-null  float64
#  32  ChildrenInHH               51047 non-null  object
#  33  HandsetRefurbished         51047 non-null  object
#  34  HandsetWebCapable          51047 non-null  object
#  35  TruckOwner                 51047 non-null  object
#  36  RVOwner                    51047 non-null  object
#  37  Homeownership              51047 non-null  object
#  38  BuysViaMailOrder           51047 non-null  object
#  39  RespondsToMailOffers       51047 non-null  object
#  40  OptOutMailings             51047 non-null  object
#  41  NonUSTravel                51047 non-null  object
#  42  OwnsComputer               51047 non-null  object
#  43  HasCreditCard              51047 non-null  object
#  44  RetentionCalls             51047 non-null  int64
#  45  RetentionOffersAccepted    51047 non-null  int64
#  46  NewCellphoneUser           51047 non-null  object
#  47  NotNewCellphoneUser        51047 non-null  object
#  48  ReferralsMadeBySubscriber  51047 non-null  int64
#  49  IncomeGroup                51047 non-null  int64
#  50  OwnsMotorcycle             51047 non-null  object
#  51  AdjustmentsToCreditRating  51047 non-null  int64
#  52  HandsetPrice               51047 non-null  object
#  53  MadeCallToRetentionTeam    51047 non-null  object
#  54  CreditRating               51047 non-null  object
#  55  PrizmCode                  51047 non-null  object
#  56  Occupation                 51047 non-null  object
#  57  MaritalStatus              51047 non-null  object
# dtypes: float64(26), int64(9), object(23)
# memory usage: 22.6+ MB

# %%
data.head(10).iloc[:, :10]
data.head(10).iloc[:, 10:20]
data.head(10).iloc[:, 20:30]
data.head(10).iloc[:, 30:40]
data.head(10).iloc[:, 40:50]
data.head(10).iloc[:, 50:] # 대략적인 데이터 구조를 확인
# Out:
#   OwnsMotorcycle  AdjustmentsToCreditRating HandsetPrice  \
# 0             No                          0           30
# 1             No                          0           30
# 2             No                          0      Unknown
# 3             No                          0           10
# 4             No                          1           10
# 5             No                          1           30
# 6             No                          1           30
# 7             No                          0           30
# 8             No                          0           80
# 9             No                          1           30
#
#   MadeCallToRetentionTeam CreditRating PrizmCode    Occupation MaritalStatus
# 0                     Yes    1-Highest  Suburban  Professional            No
# 1                      No     4-Medium  Suburban  Professional           Yes
# 2                      No       3-Good      Town        Crafts           Yes
# 3                      No     4-Medium     Other         Other            No
# 4                      No    1-Highest     Other  Professional           Yes
# 5                      No       3-Good     Other         Other           Yes
# 6                      No    1-Highest     Other          Self           Yes
# 7                      No    1-Highest     Other  Professional            No
# 8                      No    1-Highest     Other         Other           Yes
# 9                      No       3-Good     Other  Professional            No

# %%
data.isna().sum() # 결측치 확인
data.isna().sum().sum() # 결측치 최대 3515개 인거 확인 전부 drop해도 최소 약47000개 정도 남으니까 전부 drop
data = data.dropna().reset_index(drop=True)

# %%
data.duplicated().sum() # 중복값 확인, 결과는 0
# Out:
# 0

# %%
plt.subplots_adjust(wspace=0.3)
plt.pie(
    data.Churn.value_counts(),
    explode = [0, 0.05],
    labels=data.Churn.value_counts().index,
    autopct= '%1.1f%%',
    shadow= True,
    colors=['#dcdcdc', '#87ceeb']
)
# Out:
# ([<matplotlib.patches.Wedge at 0x278514faec0>,
#   <matplotlib.patches.Wedge at 0x278514fae00>],
#  [Text(-0.6842006073557579, 0.8613184828470897, 'No'),
#   Text(0.7153006349628377, -0.900469322976503, 'Yes')],
#  [Text(-0.37320033128495883, 0.4698100815529579, '71.4%'),
#   Text(0.4043003588920387, -0.5089609216823712, '28.6%')])

# %%
new_data_1 = data.filter(items=['Churn', 'CustomerID']) # CustomterID가 Index역할을 하고 있는데 혹시 범위별로 묶으면 유의미한 변수일까 확인
new_data_1.CustomerID = new_data_1.CustomerID//40000 # CustomerID 범주화 40000개씩 묶음
new_data_1

sns.countplot(
    new_data_1,
    x= 'CustomerID',
    hue= 'Churn'
)
# 범주를 묶어서 확인해 봤는데 유의미한 변화 X
# Out:
# <Axes: xlabel='CustomerID', ylabel='count'>

# %%
new_data_1 = data.filter(items=['Churn', 'CustomerID'])
new_data_1.CustomerID = new_data_1.CustomerID//4000 # 이번에는 CustomerID 4000개씩 묶음
sns.countplot(
    new_data_1,
    x= 'CustomerID',
    hue= 'Churn'
)
# 마찬가지로 의미없음
# Out:
# <Axes: xlabel='CustomerID', ylabel='count'>

# %%
data = data.drop(columns=['CustomerID']).reset_index(drop=True)
data
# Out:
#       Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0       Yes           24.00           219.0                  22.0
# 1       Yes           16.99            10.0                  17.0
# 2        No           38.00             8.0                  38.0
# 3        No           82.28          1312.0                  75.0
# 4       Yes           17.14             0.0                  17.0
# ...     ...             ...             ...                   ...
# 49747    No            0.00            76.0                  30.0
# 49748    No           31.92            63.0                  17.0
# 49749    No           71.99           724.0                  70.0
# 49750   Yes          117.49           384.0                  30.0
# 49751    No           95.17          1745.0                  85.0
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                       0.25             0.0           0.0             -157.0
# 1                       0.00             0.0           0.0               -4.0
# 2                       0.00             0.0           0.0               -2.0
# 3                       1.24             0.0           0.0              157.0
# 4                       0.00             0.0           0.0                0.0
# ...                      ...             ...           ...                ...
# 49747                   0.00             0.0           0.0                0.0
# 49748                   0.00            43.0           0.0              -38.0
# 49749                   0.00             4.0           0.9              -40.0
# 49750                   0.00           250.0           0.0                0.0
# 49751                   0.99            45.0           4.7              122.0
#
#        PercChangeRevenues  DroppedCalls  ...  ReferralsMadeBySubscriber  \
# 0                   -19.0           0.7  ...                          0
# 1                     0.0           0.3  ...                          0
# 2                     0.0           0.0  ...                          0
# 3                     8.1          52.0  ...                          0
# 4                    -0.2           0.0  ...                          0
# ...                   ...           ...  ...                        ...
# 49747                 0.0           5.7  ...                          0
# 49748               -13.2           0.7  ...                          0
# 49749                -2.0          14.3  ...                          0
# 49750                 0.0           4.0  ...                          0
# 49751                15.9          16.7  ...                          0
#
#        IncomeGroup  OwnsMotorcycle  AdjustmentsToCreditRating  HandsetPrice  \
# 0                4              No                          0            30
# 1                5              No                          0            30
# 2                6              No                          0       Unknown
# 3                6              No                          0            10
# 4                9              No                          1            10
# ...            ...             ...                        ...           ...
# 49747            4              No                          0       Unknown
# 49748            3              No                          0       Unknown
# 49749            7              No                          0       Unknown
# 49750            2              No                          0            30
# 49751            9              No                          1            60
#
#        MadeCallToRetentionTeam  CreditRating  PrizmCode    Occupation  \
# 0                          Yes     1-Highest   Suburban  Professional
# 1                           No      4-Medium   Suburban  Professional
# 2                           No        3-Good       Town        Crafts
# 3                           No      4-Medium      Other         Other
# 4                           No     1-Highest      Other  Professional
# ...                        ...           ...        ...           ...
# 49747                       No        2-High      Other  Professional
# 49748                       No        3-Good      Other         Other
# 49749                       No     1-Highest      Other  Professional
# 49750                       No         5-Low      Other  Professional
# 49751                       No        3-Good      Other         Other
#
#        MaritalStatus
# 0                 No
# 1                Yes
# 2                Yes
# 3                 No
# 4                Yes
# ...              ...
# 49747             No
# 49748            Yes
# 49749        Unknown
# 49750            Yes
# 49751             No
#
# [49752 rows x 57 columns]

# %%
# 숫자 데이터들 이상치 확인 노가다 .iloc[0] 0을 하나씩 늘려가면서 찍어봄
# 사분위 수 범위에서 크게 벗어나는 애들 제거거
sns.boxplot(
    data.loc[:, (data.dtypes != object)].iloc[:, [16]],
)
# Out:
# <Axes: >

# %%
columns_to_zscore = ['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge',
       'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls',
       'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls',
       'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 'ThreewayCalls',
       'ReceivedCalls', 'OutboundCalls', 'InboundCalls', 'PeakCallsInOut',
       'OffPeakCallsInOut', 'DroppedBlockedCalls', 'CallForwardingCalls',
       'CallWaitingCalls', 'MonthsInService', 'UniqueSubs', 'ActiveSubs',
       'Handsets', 'HandsetModels', 'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2',
       'RetentionCalls', 'RetentionOffersAccepted',
       'ReferralsMadeBySubscriber', 'IncomeGroup',
       'AdjustmentsToCreditRating']
z_scores = stats.zscore(data[columns_to_zscore])
outliers_mask = (abs(z_scores) > 3).any(axis=1)
data = data[~outliers_mask]

# %%
# 만족스럽게 제거 됐는지 확인

sns.boxplot(
    data.loc[:, (data.dtypes != object)].iloc[:, [16]],
)
# Out:
# <Axes: >

# %%
data.loc[:, (data.sum() == 0)].value_counts() # 이상치 제거 후 0으로 통일된 값들 확인
# Out:
# RetentionCalls  RetentionOffersAccepted  ReferralsMadeBySubscriber
# 0               0                        0                            37723
# Name: count, dtype: int64

# %%
data = data.drop(columns=['RetentionCalls', 'RetentionOffersAccepted', 'ReferralsMadeBySubscriber']) # drop

# %%
# 수치형데이터 확률밀도함수 확인 (데이터 분포)

sns.kdeplot(
    data,
    x= data.loc[:, (data.dtypes != object)].columns[0],
    hue='Churn'
)
# Out:
# <Axes: xlabel='MonthlyRevenue', ylabel='Density'>

# %%
# 범주형데이터 데이터 분포 확인

sns.countplot(
    data,
    x=data.loc[:, (data.dtypes == object)].columns[15],
    hue='Churn'             
)
# Out:
# <Axes: xlabel='NotNewCellphoneUser', ylabel='count'>

# %%
# object형 숫자형으로 바꿔주기
label_encoders = {}
for column in data.loc[:, (data.dtypes == object)].columns:
    label_encoder = LabelEncoder()
    data.loc[:, column] = label_encoder.fit_transform(data[column])

    label_encoders.update({column: label_encoder})

data = data.astype(dict(zip(np.extract(data.dtypes == object , data.columns), ['float']*23)))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37723 entries, 228 to 49750
# Data columns (total 54 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      37723 non-null  float64
#  1   MonthlyRevenue             37723 non-null  float64
#  2   MonthlyMinutes             37723 non-null  float64
#  3   TotalRecurringCharge       37723 non-null  float64
#  4   DirectorAssistedCalls      37723 non-null  float64
#  5   OverageMinutes             37723 non-null  float64
#  6   RoamingCalls               37723 non-null  float64
#  7   PercChangeMinutes          37723 non-null  float64
#  8   PercChangeRevenues         37723 non-null  float64
#  9   DroppedCalls               37723 non-null  float64
#  10  BlockedCalls               37723 non-null  float64
#  11  UnansweredCalls            37723 non-null  float64
#  12  CustomerCareCalls          37723 non-null  float64
#  13  ThreewayCalls              37723 non-null  float64
#  14  ReceivedCalls              37723 non-null  float64
#  15  OutboundCalls              37723 non-null  float64
#  16  InboundCalls               37723 non-null  float64
#  17  PeakCallsInOut             37723 non-null  float64
#  18  OffPeakCallsInOut          37723 non-null  float64
#  19  DroppedBlockedCalls        37723 non-null  float64
#  20  CallForwardingCalls        37723 non-null  float64
#  21  CallWaitingCalls           37723 non-null  float64
#  22  MonthsInService            37723 non-null  int64
#  23  UniqueSubs                 37723 non-null  int64
#  24  ActiveSubs                 37723 non-null  int64
#  25  ServiceArea                37723 non-null  float64
#  26  Handsets                   37723 non-null  float64
#  27  HandsetModels              37723 non-null  float64
#  28  CurrentEquipmentDays       37723 non-null  float64
#  29  AgeHH1                     37723 non-null  float64
#  30  AgeHH2                     37723 non-null  float64
#  31  ChildrenInHH               37723 non-null  float64
#  32  HandsetRefurbished         37723 non-null  float64
#  33  HandsetWebCapable          37723 non-null  float64
#  34  TruckOwner                 37723 non-null  float64
#  35  RVOwner                    37723 non-null  float64
#  36  Homeownership              37723 non-null  float64
#  37  BuysViaMailOrder           37723 non-null  float64
#  38  RespondsToMailOffers       37723 non-null  float64
#  39  OptOutMailings             37723 non-null  float64
#  40  NonUSTravel                37723 non-null  float64
#  41  OwnsComputer               37723 non-null  float64
#  42  HasCreditCard              37723 non-null  float64
#  43  NewCellphoneUser           37723 non-null  float64
#  44  NotNewCellphoneUser        37723 non-null  float64
#  45  IncomeGroup                37723 non-null  int64
#  46  OwnsMotorcycle             37723 non-null  float64
#  47  AdjustmentsToCreditRating  37723 non-null  int64
#  48  HandsetPrice               37723 non-null  float64
#  49  MadeCallToRetentionTeam    37723 non-null  float64
#  50  CreditRating               37723 non-null  float64
#  51  PrizmCode                  37723 non-null  float64
#  52  Occupation                 37723 non-null  float64
#  53  MaritalStatus              37723 non-null  float64
# dtypes: float64(49), int64(5)
# memory usage: 15.8 MB

# %%
# 인덱스 초기화
data = data.reset_index(drop=True)
data
# Out:
#        Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0        1.0           64.80           479.0                  50.0
# 1        0.0           61.02           134.0                  70.0
# 2        1.0           70.71           369.0                  50.0
# 3        1.0           61.62           674.0                  55.0
# 4        1.0           72.65           493.0                  50.0
# ...      ...             ...             ...                   ...
# 37718    1.0           38.34           320.0                  30.0
# 37719    0.0            0.00            76.0                  30.0
# 37720    0.0           31.92            63.0                  17.0
# 37721    0.0           71.99           724.0                  70.0
# 37722    1.0          117.49           384.0                  30.0
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                       0.00           139.0           0.0             -337.0
# 1                       0.50             0.0           0.0              -12.0
# 2                       7.18             0.0           3.8               -7.0
# 3                       2.97            30.0           0.0              169.0
# 4                       1.24             7.0           0.7              220.0
# ...                      ...             ...           ...                ...
# 37718                   0.99            21.0           0.0              -66.0
# 37719                   0.00             0.0           0.0                0.0
# 37720                   0.00            43.0           0.0              -38.0
# 37721                   0.00             4.0           0.9              -40.0
# 37722                   0.00           250.0           0.0                0.0
#
#        PercChangeRevenues  DroppedCalls  ...  NotNewCellphoneUser  \
# 0                   -13.3           0.7  ...                  1.0
# 1                     0.0           1.7  ...                  1.0
# 2                    -5.3           4.0  ...                  0.0
# 3                    10.3           2.7  ...                  0.0
# 4                     3.1           2.3  ...                  1.0
# ...                   ...           ...  ...                  ...
# 37718                -8.3          12.3  ...                  0.0
# 37719                 0.0           5.7  ...                  0.0
# 37720               -13.2           0.7  ...                  0.0
# 37721                -2.0          14.3  ...                  0.0
# 37722                 0.0           4.0  ...                  0.0
#
#        IncomeGroup  OwnsMotorcycle  AdjustmentsToCreditRating  HandsetPrice  \
# 0                3             0.0                          0           8.0
# 1                0             0.0                          0           8.0
# 2                0             0.0                          0           8.0
# 3                6             1.0                          1           8.0
# 4                3             0.0                          0           3.0
# ...            ...             ...                        ...           ...
# 37718            6             0.0                          0          15.0
# 37719            4             0.0                          0          15.0
# 37720            3             0.0                          0          15.0
# 37721            7             0.0                          0          15.0
# 37722            2             0.0                          0           8.0
#
#        MadeCallToRetentionTeam  CreditRating  PrizmCode  Occupation  \
# 0                          0.0           0.0        2.0         4.0
# 1                          0.0           0.0        0.0         3.0
# 2                          0.0           0.0        0.0         3.0
# 3                          0.0           0.0        2.0         3.0
# 4                          0.0           0.0        2.0         4.0
# ...                        ...           ...        ...         ...
# 37718                      0.0           0.0        0.0         4.0
# 37719                      0.0           1.0        0.0         4.0
# 37720                      0.0           2.0        0.0         3.0
# 37721                      0.0           0.0        0.0         4.0
# 37722                      0.0           4.0        0.0         4.0
#
#        MaritalStatus
# 0                2.0
# 1                1.0
# 2                1.0
# 3                2.0
# 4                0.0
# ...              ...
# 37718            0.0
# 37719            0.0
# 37720            2.0
# 37721            1.0
# 37722            2.0
#
# [37723 rows x 54 columns]

# %%
# data내보내기

data.to_csv('./data/preprocessing_train.csv', index= False)

# %%
data.shape
# Out:
# (37723, 54)

# %%
pd.read_csv('./data/preprocessing_train.csv')
# Out:
#        Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0        1.0           64.80           479.0                  50.0
# 1        0.0           61.02           134.0                  70.0
# 2        1.0           70.71           369.0                  50.0
# 3        1.0           61.62           674.0                  55.0
# 4        1.0           72.65           493.0                  50.0
# ...      ...             ...             ...                   ...
# 37718    1.0           38.34           320.0                  30.0
# 37719    0.0            0.00            76.0                  30.0
# 37720    0.0           31.92            63.0                  17.0
# 37721    0.0           71.99           724.0                  70.0
# 37722    1.0          117.49           384.0                  30.0
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                       0.00           139.0           0.0             -337.0
# 1                       0.50             0.0           0.0              -12.0
# 2                       7.18             0.0           3.8               -7.0
# 3                       2.97            30.0           0.0              169.0
# 4                       1.24             7.0           0.7              220.0
# ...                      ...             ...           ...                ...
# 37718                   0.99            21.0           0.0              -66.0
# 37719                   0.00             0.0           0.0                0.0
# 37720                   0.00            43.0           0.0              -38.0
# 37721                   0.00             4.0           0.9              -40.0
# 37722                   0.00           250.0           0.0                0.0
#
#        PercChangeRevenues  DroppedCalls  ...  NotNewCellphoneUser  \
# 0                   -13.3           0.7  ...                  1.0
# 1                     0.0           1.7  ...                  1.0
# 2                    -5.3           4.0  ...                  0.0
# 3                    10.3           2.7  ...                  0.0
# 4                     3.1           2.3  ...                  1.0
# ...                   ...           ...  ...                  ...
# 37718                -8.3          12.3  ...                  0.0
# 37719                 0.0           5.7  ...                  0.0
# 37720               -13.2           0.7  ...                  0.0
# 37721                -2.0          14.3  ...                  0.0
# 37722                 0.0           4.0  ...                  0.0
#
#        IncomeGroup  OwnsMotorcycle  AdjustmentsToCreditRating  HandsetPrice  \
# 0                3             0.0                          0           8.0
# 1                0             0.0                          0           8.0
# 2                0             0.0                          0           8.0
# 3                6             1.0                          1           8.0
# 4                3             0.0                          0           3.0
# ...            ...             ...                        ...           ...
# 37718            6             0.0                          0          15.0
# 37719            4             0.0                          0          15.0
# 37720            3             0.0                          0          15.0
# 37721            7             0.0                          0          15.0
# 37722            2             0.0                          0           8.0
#
#        MadeCallToRetentionTeam  CreditRating  PrizmCode  Occupation  \
# 0                          0.0           0.0        2.0         4.0
# 1                          0.0           0.0        0.0         3.0
# 2                          0.0           0.0        0.0         3.0
# 3                          0.0           0.0        2.0         3.0
# 4                          0.0           0.0        2.0         4.0
# ...                        ...           ...        ...         ...
# 37718                      0.0           0.0        0.0         4.0
# 37719                      0.0           1.0        0.0         4.0
# 37720                      0.0           2.0        0.0         3.0
# 37721                      0.0           0.0        0.0         4.0
# 37722                      0.0           4.0        0.0         4.0
#
#        MaritalStatus
# 0                2.0
# 1                1.0
# 2                1.0
# 3                2.0
# 4                0.0
# ...              ...
# 37718            0.0
# 37719            0.0
# 37720            2.0
# 37721            1.0
# 37722            2.0
#
# [37723 rows x 54 columns]
